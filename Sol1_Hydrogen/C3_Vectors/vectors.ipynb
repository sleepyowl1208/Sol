# %%
# %pip install numpy
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: numpy in /Users/krishnatandon/Documents/dev_env/Sol/.venv/lib/python3.13/site-packages (2.4.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in /Users/krishnatandon/Documents/dev_env/Sol/.venv/lib/python3.13/site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
x = np.array([12, 8, 92])
x
# Out:
# array([12,  8, 92])

# %%
x = np.array([12, 8, 92], dtype=np.float16)
x
# Out:
# array([12.,  8., 92.], dtype=float16)

# %%
x = np.array([12, 8, 92], dtype=np.float32)
x
# Out:
# array([12.,  8., 92.], dtype=float32)

# %%
y = np.array([12, 8, 92], dtype=np.float64)
y
# Out:
# array([12.,  8., 92.])

# %%
z = np.array([12, 8, 92], dtype=np.float64)
z
# Out:
# array([12.,  8., 92.])

# %%
a = np.array([12, 8, 92], dtype=np.float96)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = np.array([12, 8, 92], dtype=np.float96)
#       2 a
#
# File ~/Documents/dev_env/Sol/.venv/lib/python3.13/site-packages/numpy/__init__.py:792, in __getattr__(attr)
#     789     import numpy.char as char
#     790     return char.chararray
# --> 792 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'float96'

# %%
b = np.array([12, 8, 92], dtype=np.float128)
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 b = np.array([12, 8, 92], dtype=np.float128)
#       2 b
#
# File ~/Documents/dev_env/Sol/.venv/lib/python3.13/site-packages/numpy/__init__.py:792, in __getattr__(attr)
#     789     import numpy.char as char
#     790     return char.chararray
# --> 792 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'float128'
